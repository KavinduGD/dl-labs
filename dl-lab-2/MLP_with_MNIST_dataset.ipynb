# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten
from tensorflow.keras.utils import to_categorical
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# Load the MNIST dataset

# %%
(train_data,train_target),(test_data,test_target) = mnist.load_data()

# %% [markdown]
# Visualize the dataset

# %%
fig, axs = plt.subplots(2, 5, figsize=(16,8))
random_numbers = np.random.randint(0, 60000, 10)
print('Target labels: ',train_target[random_numbers])
for idx, ax in enumerate(axs.ravel()):
    ax.imshow(train_data[random_numbers[idx]],cmap='gray')
plt.show()
# Out:
# Target labels:  [0 9 5 0 6 5 3 2 5 0]

# %% [markdown]
# Pre-processing stage

# %%
new_train_data = train_data/255.0
new_test_data=test_data/255.0

new_train_target = to_categorical(train_target)
new_test_target = to_categorical(test_target)

# %% [markdown]
# Create the Model architecture

# %%
model=Sequential()

model.add(Flatten(input_shape=(28,28)))

model.add(Dense(64,activation='relu'))
model.add(Dense(64,input_dim=64,activation='relu'))
model.add(Dense(32,input_dim=64,activation='relu'))
model.add(Dense(10,input_dim=32,activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_4 (Flatten)                  │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 64)                  │          50,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 10)                  │             330 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 56,810 (221.91 KB)
#  Trainable params: 56,810 (221.91 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Train the model

# %%
train_info = model.fit(new_train_data , new_train_target , epochs = 10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.8464 - loss: 0.5193
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9603 - loss: 0.1344
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9720 - loss: 0.0914
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9791 - loss: 0.0686
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9814 - loss: 0.0604
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9836 - loss: 0.0528
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9869 - loss: 0.0410
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9877 - loss: 0.0375
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9879 - loss: 0.0349
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9905 - loss: 0.0282

# %% [markdown]
# Plot the loss and accuracy graphs

# %%
plt.plot(train_info.history['loss'])
plt.xlabel('epochs')
plt.ylabel('loss')
plt.title('Model loss')
plt.show()

# %%
plt.plot(train_info.history['accuracy'])
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.title('Model accuracy')
plt.show()

# %% [markdown]
# Test the performance of Model

# %%
loss, acc = model.evaluate(new_test_data , new_test_target)
print(f'Loss of the Test dataset is: {loss}\nAccuracy of the test dataset is: {acc}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.9688 - loss: 0.1035
# Loss of the Test dataset is: 0.09046059101819992
# Accuracy of the test dataset is: 0.9739000201225281

# %% [markdown]
# Save the model weights

# %%
model.save_weights('MNIST_WEIGHTS_V1.weights.h5')

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l1, l2
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist
from sklearn.metrics import confusion_matrix

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images = train_images / 255.0
test_images = test_images / 255.0
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

model = Sequential()
model.add(Flatten(input_shape=(28, 28)))
model.add(Dense(128, activation='relu', kernel_regularizer=l1(0.001)))
model.add(Dense(128, activation='relu', kernel_regularizer=l2(0.001)))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_images, train_labels, 
                    epochs=30, 
                    batch_size=64, 
                    validation_split=0.2, 
                    verbose=2)


test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=0)
print(f'Test accuracy: {test_acc:.4f}')

predicted_classes = model.predict(test_images)
predicted_classes = np.argmax(predicted_classes, axis=1)
true_classes = np.argmax(test_labels, axis=1)
# Out:
# C:\Users\kavin\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 750/750 - 3s - 4ms/step - accuracy: 0.8872 - loss: 1.1434 - val_accuracy: 0.9169 - val_loss: 0.6513
# Epoch 2/30
# 750/750 - 2s - 2ms/step - accuracy: 0.9280 - loss: 0.5863 - val_accuracy: 0.9451 - val_loss: 0.5038
# Epoch 3/30
# 750/750 - 2s - 2ms/step - accuracy: 0.9408 - loss: 0.4860 - val_accuracy: 0.9541 - val_loss: 0.4309
# Epoch 4/30
# 750/750 - 2s - 2ms/step - accuracy: 0.9481 - loss: 0.4263 - val_accuracy: 0.9534 - val_loss: 0.4010
# Epoch 5/30
# 750/750 - 2s - 2ms/step - accuracy: 0.9514 - loss: 0.3965 - val_accuracy: 0.9575 - val_loss: 0.3668
# Epoch 6/30
# 750/750 - 2s - 2ms/step - accuracy: 0.9545 - loss: 0.3736 - val_accuracy: 0.9577 - val_loss: 0.3572
# Epoch 7/30
# 750/750 - 2s - 2ms/step - accuracy: 0.9565 - loss: 0.3586 - val_accuracy: 0.9523 - val_loss: 0.3610
# Epoch 8/30
# 750/750 - 1s - 2ms/step - accuracy: 0.9588 - loss: 0.3442 - val_accuracy: 0.9605 - val_loss: 0.3334
# Epoch 9/30
# 750/750 - 1s - 2ms/step - accuracy: 0.9586 - loss: 0.3385 - val_accuracy: 0.9635 - val_loss: 0.3211
# Epoch 10/30
# 750/750 - 1s - 2ms/step - accuracy: 0.9599 - loss: 0.3301 - val_accuracy: 0.9607 - val_loss: 0.3181
# Epoch 11/30
# 750/750 - 1s - 2ms/step - accuracy: 0.9612 - loss: 0.3211 - val_accuracy: 0.9503 - val_loss: 0.3483
# Epoch 12/30
# 750/750 - 1s - 2ms/step - accuracy: 0.9619 - loss: 0.3189 - val_accuracy: 0.9600 - val_loss: 0.3200
# Epoch 13/30
# 750/750 - 1s - 2ms/step - accuracy: 0.9630 - loss: 0.3136 - val_accuracy: 0.9607 - val_loss: 0.3217
# Epoch 14/30
# 750/750 - 1s - 2ms/step - accuracy: 0.9621 - loss: 0.3100 - val_accuracy: 0.9661 - val_loss: 0.2982
# Epoch 15/30
# 750/750 - 1s - 2ms/step - accuracy: 0.9636 - loss: 0.3036 - val_accuracy: 0.9590 - val_loss: 0.3169
# Epoch 16/30
# 750/750 - 1s - 2ms/step - accuracy: 0.9637 - loss: 0.3004 - val_accuracy: 0.9611 - val_loss: 0.3059
# Epoch 17/30
# 750/750 - 1s - 2ms/step - accuracy: 0.9640 - loss: 0.2998 - val_accuracy: 0.9638 - val_loss: 0.2951
# Epoch 18/30
# 750/750 - 1s - 2ms/step - accuracy: 0.9645 - loss: 0.2951 - val_accuracy: 0.9592 - val_loss: 0.3145
# Epoch 19/30
# 750/750 - 1s - 2ms/step - accuracy: 0.9654 - loss: 0.2921 - val_accuracy: 0.9588 - val_loss: 0.3099
# Epoch 20/30
# 750/750 - 1s - 2ms/step - accuracy: 0.9662 - loss: 0.2866 - val_accuracy: 0.9630 - val_loss: 0.2910
# Epoch 21/30
# 750/750 - 1s - 2ms/step - accuracy: 0.9642 - loss: 0.2897 - val_accuracy: 0.9664 - val_loss: 0.2900
# Epoch 22/30
# 750/750 - 1s - 2ms/step - accuracy: 0.9661 - loss: 0.2852 - val_accuracy: 0.9598 - val_loss: 0.3001
# Epoch 23/30
# 750/750 - 1s - 2ms/step - accuracy: 0.9658 - loss: 0.2828 - val_accuracy: 0.9617 - val_loss: 0.2949
# Epoch 24/30
# 750/750 - 1s - 2ms/step - accuracy: 0.9668 - loss: 0.2805 - val_accuracy: 0.9647 - val_loss: 0.2810
# Epoch 25/30
# 750/750 - 1s - 2ms/step - accuracy: 0.9660 - loss: 0.2791 - val_accuracy: 0.9644 - val_loss: 0.2882
# Epoch 26/30
# 750/750 - 1s - 2ms/step - accuracy: 0.9664 - loss: 0.2807 - val_accuracy: 0.9658 - val_loss: 0.2798
# Epoch 27/30
# 750/750 - 1s - 2ms/step - accuracy: 0.9665 - loss: 0.2772 - val_accuracy: 0.9669 - val_loss: 0.2821
# Epoch 28/30
# 750/750 - 1s - 2ms/step - accuracy: 0.9664 - loss: 0.2744 - val_accuracy: 0.9653 - val_loss: 0.2845
# Epoch 29/30
# 750/750 - 1s - 2ms/step - accuracy: 0.9672 - loss: 0.2742 - val_accuracy: 0.9562 - val_loss: 0.3049
# Epoch 30/30
# 750/750 - 1s - 2ms/step - accuracy: 0.9672 - loss: 0.2730 - val_accuracy: 0.9639 - val_loss: 0.2825
# Test accuracy: 0.9670
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()


plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

def plot_confusion_matrix(true_labels, predicted_labels, classes):
    conf_matrix = confusion_matrix(true_labels, predicted_labels)
    disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=classes)
    disp.plot(cmap='Blues')
    plt.title('Confusion Matrix')
    plt.show()

class_names = [str(i) for i in range(10)]

plot_confusion_matrix(true_classes, predicted_classes, class_names)
